# %%
#import the package "Pandas" into Jupyter Notebook
import pandas as pd

# %%
#We import the stock data of Facebook into Jupyter Notebook. The CSV file is located in the folder called "Data" in our Workspace
#We then name the DataFrame name as 'fb'
fb = pd.DataFrame.from_csv('../data/facebook.csv')

# %%
#We import the stock data of Microsoft into Jupyter Notebook. The CSV file is located in the folder called "Data" in our Workspace
ms = pd.DataFrame.from_csv('../data/microsoft.csv')

# %%
# run this cell to ensure Microsoft's stock data is imported
print(ms.iloc[0, 0])
# Out:
# 46.73
